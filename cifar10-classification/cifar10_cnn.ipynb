# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 700s 4us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=0, shuffle=True)
# Out:
# Epoch 00001: val_loss improved from inf to 1.32750, saving model to model.weights.best.hdf5
#
# Epoch 00002: val_loss improved from 1.32750 to 1.18046, saving model to model.weights.best.hdf5
#
# Epoch 00003: val_loss improved from 1.18046 to 1.04728, saving model to model.weights.best.hdf5
#
# Epoch 00004: val_loss did not improve from 1.04728
#
# Epoch 00005: val_loss did not improve from 1.04728
#
# Epoch 00006: val_loss improved from 1.04728 to 0.95865, saving model to model.weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.95865 to 0.93550, saving model to model.weights.best.hdf5
#
# Epoch 00008: val_loss did not improve from 0.93550
#
# Epoch 00009: val_loss did not improve from 0.93550
#
# Epoch 00010: val_loss did not improve from 0.93550
#
# Epoch 00011: val_loss improved from 0.93550 to 0.91873, saving model to model.weights.best.hdf5
#
# Epoch 00012: val_loss did not improve from 0.91873
#
# Epoch 00013: val_loss did not improve from 0.91873
#
# Epoch 00014: val_loss did not improve from 0.91873
#
# Epoch 00015: val_loss did not improve from 0.91873
#
# Epoch 00016: val_loss did not improve from 0.91873
#
# Epoch 00017: val_loss did not improve from 0.91873
#
# Epoch 00018: val_loss did not improve from 0.91873
#
# Epoch 00019: val_loss did not improve from 0.91873
#
# Epoch 00020: val_loss did not improve from 0.91873
#
# Epoch 00021: val_loss did not improve from 0.91873
#
# Epoch 00022: val_loss did not improve from 0.91873
#
# Epoch 00023: val_loss did not improve from 0.91873
#
# Epoch 00024: val_loss did not improve from 0.91873
#
# Epoch 00025: val_loss did not improve from 0.91873
#
# Epoch 00026: val_loss did not improve from 0.91873
#
# Epoch 00027: val_loss did not improve from 0.91873
#
# Epoch 00028: val_loss did not improve from 0.91873
#
# Epoch 00029: val_loss did not improve from 0.91873
#
# Epoch 00030: val_loss did not improve from 0.91873
#
# Epoch 00031: val_loss did not improve from 0.91873
#
# Epoch 00032: val_loss did not improve from 0.91873
#
# Epoch 00033: val_loss did not improve from 0.91873
#
# Epoch 00034: val_loss did not improve from 0.91873
#
# Epoch 00035: val_loss did not improve from 0.91873
#
# Epoch 00036: val_loss did not improve from 0.91873
#
# Epoch 00037: val_loss did not improve from 0.91873
#
# Epoch 00038: val_loss did not improve from 0.91873
#
# Epoch 00039: val_loss did not improve from 0.91873
#
# Epoch 00040: val_loss did not improve from 0.91873
#
# Epoch 00041: val_loss did not improve from 0.91873
#
# Epoch 00042: val_loss did not improve from 0.91873
#
# Epoch 00043: val_loss did not improve from 0.91873
#
# Epoch 00044: val_loss did not improve from 0.91873
#
# Epoch 00045: val_loss did not improve from 0.91873
#
# Epoch 00046: val_loss did not improve from 0.91873
#
# Epoch 00047: val_loss did not improve from 0.91873
#
# Epoch 00048: val_loss did not improve from 0.91873
#
# Epoch 00049: val_loss did not improve from 0.91873
#
# Epoch 00050: val_loss did not improve from 0.91873
#
# Epoch 00051: val_loss did not improve from 0.91873
#
# Epoch 00052: val_loss did not improve from 0.91873
#
# Epoch 00053: val_loss did not improve from 0.91873
#
# Epoch 00054: val_loss did not improve from 0.91873
#
# Epoch 00055: val_loss did not improve from 0.91873
#
# Epoch 00056: val_loss did not improve from 0.91873
#
# Epoch 00057: val_loss did not improve from 0.91873
#
# Epoch 00058: val_loss did not improve from 0.91873
#
# Epoch 00059: val_loss did not improve from 0.91873
#
# Epoch 00060: val_loss did not improve from 0.91873
#
# Epoch 00061: val_loss did not improve from 0.91873
#
# Epoch 00062: val_loss did not improve from 0.91873
#
# Epoch 00063: val_loss did not improve from 0.91873
#
# Epoch 00064: val_loss did not improve from 0.91873
#
# Epoch 00065: val_loss did not improve from 0.91873
#
# Epoch 00066: val_loss did not improve from 0.91873
#
# Epoch 00067: val_loss did not improve from 0.91873
#
# Epoch 00068: val_loss did not improve from 0.91873
#
# Epoch 00069: val_loss did not improve from 0.91873
#
# Epoch 00070: val_loss did not improve from 0.91873
#
# Epoch 00071: val_loss did not improve from 0.91873
#
# Epoch 00072: val_loss did not improve from 0.91873
#
# Epoch 00073: val_loss did not improve from 0.91873
#
# Epoch 00074: val_loss did not improve from 0.91873
#
# Epoch 00075: val_loss did not improve from 0.91873
#
# Epoch 00076: val_loss did not improve from 0.91873
#
# Epoch 00077: val_loss did not improve from 0.91873
#
# Epoch 00078: val_loss did not improve from 0.91873
#
# Epoch 00079: val_loss did not improve from 0.91873
#
# Epoch 00080: val_loss did not improve from 0.91873
#
# Epoch 00081: val_loss did not improve from 0.91873
#
# Epoch 00082: val_loss did not improve from 0.91873
#
# Epoch 00083: val_loss did not improve from 0.91873
#
# Epoch 00084: val_loss did not improve from 0.91873
#
# Epoch 00085: val_loss did not improve from 0.91873
#
# Epoch 00086: val_loss did not improve from 0.91873
#
# Epoch 00087: val_loss did not improve from 0.91873
#
# Epoch 00088: val_loss did not improve from 0.91873
#
# Epoch 00089: val_loss did not improve from 0.91873
#
# Epoch 00090: val_loss did not improve from 0.91873
#
# Epoch 00091: val_loss did not improve from 0.91873
#
# Epoch 00092: val_loss did not improve from 0.91873
#
# Epoch 00093: val_loss did not improve from 0.91873
#
# Epoch 00094: val_loss did not improve from 0.91873
#
# Epoch 00095: val_loss did not improve from 0.91873
#
# Epoch 00096: val_loss did not improve from 0.91873
#
# Epoch 00097: val_loss did not improve from 0.91873
#
# Epoch 00098: val_loss did not improve from 0.91873
#
# Epoch 00099: val_loss did not improve from 0.91873
#
# Epoch 00100: val_loss did not improve from 0.91873

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6736999750137329

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
